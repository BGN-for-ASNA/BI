# %%
import jax.numpy as jnp
import networkx as nx
import os
import sys
newPath = os.path.dirname(os.path.abspath(""))
if newPath not in sys.path:
    sys.path.append(newPath)
from BEE import bee
m = bee(platform='cpu')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 if newPath not in sys.path:
#       7     sys.path.append(newPath)
# ----> 8 from BI import bi
#       9 m = bi(platform='cpu')
#
# ModuleNotFoundError: No module named 'BI'

# %% [markdown]
# # Data simulation

# %%
import numpy as np

# Generate synthetic data with Multivariate Normal Distribution
def generate_synthetic_data(n_locations=100,
    cluster_means={
        'visits': [80, 80, 20, 20],
        'assoc_prop': [0.8, 0.2, 0.8, 0.2]
    },
    cluster_stds={
        'visits': [10, 10, 5, 5],
        'assoc_prop': [0.1, 0.1, 0.1, 0.1]
    },
    covariances=[0.5, 0.5, 0.2, 0.2],  # Define covariances for each cluster
    seed=0):
    """Generates synthetic data by creating four clusters with specific mean and standard deviation values for two features (visits and assoc_prop).
    
    Args:
        n_locations (int): Number of locations to generate.
        cluster_means (dict): Contains predefined mean values for each cluster's center for the two features.
        cluster_stds (dict): Contains the standard deviations for each cluster.
        covariances (list): Covariances between 'visits' and 'assoc_prop' for each cluster.
        random_seed (int): Seed for random number generation.
    
    Returns:
        np.array: Generated data points.
        np.array: True labels for each data point.
    """

    np.random.seed(seed)
    n_per_cluster = n_locations // 4
    data = []
    true_labels = []
    
    # Generate data for each cluster
    for i in range(4):
        mean_vector = [cluster_means['visits'][i], cluster_means['assoc_prop'][i]]
        cov_matrix = [
            [cluster_stds['visits'][i] ** 2, covariances[i] * cluster_stds['visits'][i] * cluster_stds['assoc_prop'][i]],
            [covariances[i] * cluster_stds['visits'][i] * cluster_stds['assoc_prop'][i], cluster_stds['assoc_prop'][i] ** 2]
        ]
        
        # Generate n_per_cluster samples from the multivariate normal distribution
        samples = np.random.multivariate_normal(mean_vector, cov_matrix, n_per_cluster)
        
        # Ensure proportions are between 0 and 1
        samples[:, 1] = np.clip(samples[:, 1], 0, 1)
        
        data.extend(samples)
        true_labels.extend([i] * n_per_cluster)
    
    return np.array(data), np.array(true_labels)

# Plotting function remains the same
def plot_synthetic_data(X, true_labels):
    import matplotlib.pyplot as plt

    visits = X[:, 0]
    assoc_prop = X[:, 1]

    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(visits, assoc_prop, c=true_labels, cmap='viridis', s=50, alpha=0.7)
    plt.colorbar(scatter, label="True Cluster Labels")
    plt.xlabel("Visits")
    plt.ylabel("Association Proportion")
    plt.title("Scatter Plot of Visits vs. Association Proportion, Colored by True Labels")
    plt.show()

# Generate and plot the data
data, true_labels = generate_synthetic_data(
    seed = 1000,
    cluster_means={
        'visits': [80, 80, 40, 40],
        'assoc_prop': [0.8, 0.2, 0.8, 0.2]
    }
)
plot_synthetic_data(data, true_labels)

# %% [markdown]
# # Multivariate Gaussian Mixture Model (GMM)

# %%
from main import *
import numpyro
import numpyro.distributions as dists
import jax
import jax.numpy as jnp
from numpyro.infer import MCMC, NUTS, Predictive
from numpyro.ops.indexing import Vindex
import numpy as np

m = bee(platform='cpu')
def simData(n = 100, dim = 2, k = 3, p_real = [0.1, 0.5, 0.4], mus = [[10,10], [5,5], [1,1]], sigmas = [1,0.5], seed = 0):
    """
    Simulate data from a mixture of Gaussians.
    
    Parameters
    ----------
    n : int
        Number of samples.
    dim : int
        Dimensionality of the data.
    k : int
        Number of mixture components.
    p_real : array-like, shape (k,)
        Probability of each mixture component.
    sigma : array-like, shape (dim,)
        Standard deviation of the noise.
    mus : array-like, shape (k, dim)
        Means of the mixture components on each dimension.
    sigmas : array-like, shape (k,)
        Standard deviations of the mixture components on each groups.
        
    Returns
    -------
    data : array-like, shape (n, dim)
        Simulated data.
        
    """
    key = jax.random.key(seed)
    seeds = jax.random.randint(key, (100,), 0, 10000)

    mus = jnp.array(mus)
    sigmas = jnp.array(sigmas)
    p_real = jnp.array(p_real)    

    clusters = bee.dist.categorical(probs = p_real, sample = True, shape=(n,))
    s_clusters = sigmas[clusters]
    m_clusters = mus[clusters]
    
    return vmap(lambda x, y, z  : bee.dist.multivariatenormal(x, jnp.diag(jnp.repeat(y, dim)), sample = True, seed = z))(m_clusters, s_clusters, seeds), clusters

def plot_synthetic_data(X, true_labels):
    import matplotlib.pyplot as plt

    visits = X[:, 0]
    assoc_prop = X[:, 1]

    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(visits, assoc_prop, c=true_labels, cmap='viridis', s=50, alpha=0.7)
    plt.colorbar(scatter, label="True Cluster Labels")
    plt.xlabel("Visits")
    plt.ylabel("Association Proportion")
    plt.title("Scatter Plot of Visits vs. Association Proportion, Colored by True Labels")
    plt.show()
# Out:
# jax.local_device_count 32

# %%
data, true_labels =  simData(n = 100, dim = 2, k = 4, 
p_real = [0.50, 0.10, 0.30, 0.10], 
mus = [[10,10], [0,10], [0,1] , [10,0]], 
sigmas = [0.5,0.5, 0.5,0.5])
plot_synthetic_data(data, true_labels)

# %%
N, dim = data.shape
K = 4
sample = True
p_real = [0.25, 0.25, 0.25, 0.25]
mus = jnp.array([[10,10], [0,10], [0,1] , [10,0]])
sigmas = jnp.array([[0.5,0.2], [0.5,0.2], [0.5,0.2] , [0.5,0.2]])
cluster_proba = jnp.array(p_real)

# %%
#cluster_proba = bee.dist.dirichlet(weight * jnp.ones(K), sample=sample, name = 'cluster_proba')
cluster_proba = jnp.array(p_real)
#mus = bee.dist.multivariatenormal(0, 10*jnp.eye(dim), sample = sample, shape = (K, ), name= 'locs') # KxD
#sigmas = bee.dist.halfcauchy(scale=10, sample = sample, shape=(K, dim), name = 'sigma')# KxD

assignment = bee.dist.categorical(cluster_proba, sample = sample, shape = (N,), name='assignment')
sigma_expanded = vmap(lambda x: x * jnp.eye(dim) )(sigmas[assignment])
tmp = mus[assignment]
tmp = tmp.reshape(dim, N).T
data = bee.dist.multivariatenormal(tmp, sigma_expanded, sample = True)

# %%
plot_synthetic_data(data, assignment)

# %% [markdown]
# #  BI not working
#
# Due to numpyro specificities in latent variable, this can't run with BI, mainly due to plate function.

# %%
from numpyro.ops.indexing import Vindex
weight = 0.5
K = 4
def model(data = data, weight = 0.5, K = 4):

    N, dim = data.shape
    cluster_proba = bee.dist.dirichlet(weight * jnp.ones(K), name = 'cluster_proba')
     
    locs = bee.dist.multivariatenormal(jnp.zeros(dim), 10*jnp.eye(dim), name= 'locs', shape = (K, dim))
    sigma = bee.dist.halfcauchy(scale=10, name = 'sigma', shape = (K, dim))  
    
    assignment = bee.dist.categorical(cluster_proba, shape = (N,), name='assignment')          
    #sigma_expanded = vmap(lambda x: x * jnp.eye(dim) )(sigma[assignment])
    sigma_expanded = Vindex(sigma)[assignment][..., None, None] * jnp.eye(dim)
    lk('obs',  MultivariateNormal(Vindex(locs)[assignment], sigma_expanded), obs = data)


m = bee(platform='cpu')
m.run(model)
m.summary()

#from main import *
#a = dist.normal( 178, 20, name = 'a',shape= [1], sample = True)
#b = dist.lognormal(  0, 1, name = 'b',shape= [1]  , sample = True )
#s = dist.uniform( 0, 50, name = 's',shape = [1], sample = True)
##lk("y", Normal(a + b * weight , s), obs=height)
# Out:
# jax.local_device_count 32
# ArrayImpl
# float
# int
# /home/sosa/work/BI/bi/main.py:122: FutureWarning: Some algorithms will automatically enumerate the discrete latent site assignment of your model. In the future, enumerated sites need to be marked with `infer={'enumerate': 'parallel'}`.
#   self.sampler.run(jax.random.PRNGKey(seed), **self.data_on_model)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 19
#      15     lk('obs',  MultivariateNormal(Vindex(locs)[assignment], sigma_expanded), obs = data)
#      18 m = bi(platform='cpu')
# ---> 19 m.run(model)
#      20 m.summary()
#      22 #from main import *
#      23 #a = dist.normal( 178, 20, name = 'a',shape= [1], sample = True)
#      24 #b = dist.lognormal(  0, 1, name = 'b',shape= [1]  , sample = True )
#      25 #s = dist.uniform( 0, 50, name = 's',shape = [1], sample = True)
#      26 ##lk("y", Normal(a + b * weight , s), obs=height)
#
# File ~/work/BI/bi/main.py:122, in bi.run(self, model, potential_fn, kinetic_fn, step_size, inverse_mass_matrix, adapt_step_size, adapt_mass_matrix, dense_mass, target_accept_prob, trajectory_length, max_tree_depth, init_strategy, find_heuristic_step_size, forward_mode_differentiation, regularize_mass_matrix, num_warmup, num_samples, num_chains, thinning, postprocess_fn, chain_method, progress_bar, jit_model_args, seed)
#      96     self.data_on_model = self.pd_to_jax(self.model)
#      98 self.sampler = MCMC(NUTS(self.model,
#      99                         potential_fn=potential_fn,
#     100                         kinetic_fn=kinetic_fn,
#    (...)
#     119                         progress_bar=progress_bar,
#     120                         jit_model_args=jit_model_args)
# --> 122 self.sampler.run(jax.random.PRNGKey(seed), **self.data_on_model)
#     123 self.posteriors = self.sampler.get_samples()
#
# File ~/.local/lib/python3.10/site-packages/numpyro/infer/mcmc.py:644, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     642 map_args = (rng_key, init_state, init_params)
#     643 if self.num_chains == 1:
# --> 644     states_flat, last_state = partial_map_fn(map_args)
#     645     states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#     646 else:
#
# File ~/.local/lib/python3.10/site-packages/numpyro/infer/mcmc.py:426, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     424 # Check if _sample_fn is None, then we need to initialize the sampler.
#     425 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 426     new_init_state = self.sampler.init(
#     427         rng_key,
#     428         self.num_warmup,
#     429         init_params,
#     430         model_args=args,
#     431         model_kwargs=kwargs,
#     432     )
#     433     init_state = new_init_state if init_state is None else init_state
#     434 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File ~/.local/lib/python3.10/site-packages/numpyro/infer/hmc.py:743, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     738 # vectorized
#     739 else:
#     740     rng_key, rng_key_init_model = jnp.swapaxes(
#     741         vmap(random.split)(rng_key), 0, 1
#     742     )
# --> 743 init_params = self._init_state(
#     744     rng_key_init_model, model_args, model_kwargs, init_params
#     745 )
#     746 if self._potential_fn and init_params is None:
#     747     raise ValueError(
#     748         "Valid value of `init_params` must be provided with" " `potential_fn`."
#     749     )
#
# File ~/.local/lib/python3.10/site-packages/numpyro/infer/hmc.py:687, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     680 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     681     if self._model is not None:
#     682         (
#     683             new_init_params,
#     684             potential_fn,
#     685             postprocess_fn,
#     686             model_trace,
# --> 687         ) = initialize_model(
#     688             rng_key,
#     689             self._model,
#     690             dynamic_args=True,
#     691             init_strategy=self._init_strategy,
#     692             model_args=model_args,
#     693             model_kwargs=model_kwargs,
#     694             forward_mode_differentiation=self._forward_mode_differentiation,
#     695         )
#     696         if init_params is None:
#     697             init_params = new_init_params
#
# File ~/.local/lib/python3.10/site-packages/numpyro/infer/util.py:680, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     678     if not isinstance(model, enum):
#     679         max_plate_nesting = _guess_max_plate_nesting(model_trace)
# --> 680         _validate_model(model_trace, plate_warning="error")
#     681         model = enum(config_enumerate(model), -max_plate_nesting - 1)
#     682 else:
#
# File ~/.local/lib/python3.10/site-packages/numpyro/util.py:560, in _validate_model(model_trace, plate_warning)
#     553 message = (
#     554     f"Missing a plate statement for batch dimension {dim}"
#     555     f" at site '{name}'. You can use `numpyro.util.format_shapes`"
#     556     " utility to check shapes at all sites of your model."
#     557 )
#     559 if plate_warning == "error":
# --> 560     raise ValueError(message)
#     561 elif plate_warning == "strict" or (len(plate_dims) > 0):
#     562     warnings.warn(message, stacklevel=find_stack_level())
#
# ValueError: Missing a plate statement for batch dimension -1 at site 'locs'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.

# %%
def model(K = 4, data=data, weight = 0.25):
    N, dim = data.shape
    cluster_proba = bee.dist.dirichlet(weight * jnp.ones(K), name = 'cluster_proba')
    

    with numpyro.plate('components', K, dim= -1 ):
        locs =  bee.dist.multivariatenormal(jnp.zeros(dim), 10 * jnp.eye(dim), name='locs')
        sigma = bee.dist.halfcauchy(scale=10, name='sigma') # TODO: Need to set up a different sigma for each axes.!!!!!!!!!!!!!!!!

    
    with numpyro.plate('data', N):
        assignment = bee.dist.categorical(cluster_proba, name = 'assignment')
        
        # Correctly broadcast sigma to create covariance matrices
        sigma_expanded = Vindex(sigma)[assignment][..., None, None] * jnp.eye(dim)
        
        numpyro.sample('obs',  MultivariateNormal(Vindex(locs)[assignment], sigma_expanded), obs=data)

m = bee(platform='cpu')
m.run(model)
m.summary()

# %% [markdown]
# # TFP

# %%
# %matplotlib inline


import functools

import matplotlib.pyplot as plt; plt.style.use('ggplot')
import numpy as np
import seaborn as sns; sns.set_context('notebook')

import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()
import tensorflow_probability as tfp

tfd = tfp.distributions
tfb = tfp.bijectors

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)

class MVNCholPrecisionTriL(tfd.TransformedDistribution):
  """MVN from loc and (Cholesky) precision matrix."""

  def __init__(self, loc, chol_precision_tril, name=None):
    super(MVNCholPrecisionTriL, self).__init__(
        distribution=tfd.Independent(tfd.Normal(tf.zeros_like(loc),
                                                scale=tf.ones_like(loc)),
                                     reinterpreted_batch_ndims=1),
        bijector=tfb.Chain([
            tfb.Shift(shift=loc),
            tfb.Invert(tfb.ScaleMatvecTriL(scale_tril=chol_precision_tril,
                                           adjoint=True)),
        ]),
        name=name)

dtype = np.float64
dims = 2
components = 4
num_samples = 100   

bgmm = tfd.JointDistributionNamed(dict(
  mix_probs=tfd.Dirichlet(
    concentration=np.ones(components, dtype) / 10.),
  loc=tfd.Independent(
    tfd.Normal(
        loc=np.stack([
            -np.ones(dims, dtype),
            np.zeros(dims, dtype),
            np.ones(dims, dtype),
        ]),
        scale=tf.ones([components, dims], dtype)),
    reinterpreted_batch_ndims=2),
  precision=tfd.Independent(
    tfd.WishartTriL(
        df=5,
        scale_tril=np.stack([np.eye(dims, dtype=dtype)]*components),
        input_output_cholesky=True),
    reinterpreted_batch_ndims=1),
  s=lambda mix_probs, loc, precision: tfd.Sample(tfd.MixtureSameFamily(
      mixture_distribution=tfd.Categorical(probs=mix_probs),
      components_distribution=MVNCholPrecisionTriL(
          loc=loc,
          chol_precision_tril=precision)),
      sample_shape=num_samples)
))

def joint_log_prob(observations, mix_probs, loc, chol_precision):
  """BGMM with priors: loc=Normal, precision=Inverse-Wishart, mix=Dirichlet.

  Args:
    observations: `[n, d]`-shaped `Tensor` representing Bayesian Gaussian
      Mixture model draws. Each sample is a length-`d` vector.
    mix_probs: `[K]`-shaped `Tensor` representing random draw from
      `Dirichlet` prior.
    loc: `[K, d]`-shaped `Tensor` representing the location parameter of the
      `K` components.
    chol_precision: `[K, d, d]`-shaped `Tensor` representing `K` lower
      triangular `cholesky(Precision)` matrices, each being sampled from
      a Wishart distribution.

  Returns:
    log_prob: `Tensor` representing joint log-density over all inputs.
  """
  return bgmm.log_prob(
      mix_probs=mix_probs, loc=loc, precision=chol_precision, s=observations)

unnormalized_posterior_log_prob = functools.partial(joint_log_prob, data)

initial_state = [
    tf.fill([components],
            value=np.array(1. / components, dtype),
            name='mix_probs'),
    tf.constant(np.array([[-2., -2],
                          [0, 0],
                          [2, 2]], dtype),
                name='loc'),
    tf.linalg.eye(dims, batch_shape=[components], dtype=dtype, name='chol_precision'),
]

unconstraining_bijectors = [
    tfb.SoftmaxCentered(),
    tfb.Identity(),
    tfb.Chain([
        tfb.TransformDiagonal(tfb.Softplus()),
        tfb.FillTriangular(),
    ])]

@tf.function(autograph=False)
def sample():
  return tfp.mcmc.sample_chain(
    num_results=2000,
    num_burnin_steps=500,
    current_state=initial_state,
    kernel=tfp.mcmc.SimpleStepSizeAdaptation(
        tfp.mcmc.TransformedTransitionKernel(
            inner_kernel=tfp.mcmc.HamiltonianMonteCarlo(
                target_log_prob_fn=unnormalized_posterior_log_prob,
                 step_size=0.065,
                 num_leapfrog_steps=5),
            bijector=unconstraining_bijectors),
         num_adaptation_steps=400),
    trace_fn=lambda _, pkr: pkr.inner_results.inner_results.is_accepted)

[mix_probs, loc, chol_precision], is_accepted = sample()

# %%
tf.fill([components],
            value=np.array(1. / components, dtype),
            name='mix_probs')
# Out:
# <tf.Tensor: shape=(3,), dtype=float64, numpy=array([0.33333333, 0.33333333, 0.33333333])>

# %%
acceptance_rate = tf.reduce_mean(tf.cast(is_accepted, dtype=tf.float32)).numpy()
mean_mix_probs = tf.reduce_mean(mix_probs, axis=0).numpy()
mean_loc = tf.reduce_mean(loc, axis=0).numpy()
mean_chol_precision = tf.reduce_mean(chol_precision, axis=0).numpy()
precision = tf.linalg.matmul(chol_precision, chol_precision, transpose_b=True)

# %%
print('acceptance_rate:', acceptance_rate)
print('avg mix probs:', mean_mix_probs)
print('avg loc:\n', mean_loc)
print('avg chol(precision):\n', mean_chol_precision)
# Out:
# acceptance_rate: 0.3185
# avg mix probs: [0.00172675 0.19583991 0.80243334]
# avg loc:
#  [[-1.49031505 -1.06764643]
#  [-0.10921596  0.12521602]
#  [ 5.94872053  5.85198557]]
# avg chol(precision):
#  [[[ 1.63874389  0.        ]
#   [-0.56583613  1.33019451]]
#
#  [[ 1.54157123  0.        ]
#   [-0.41837523  1.79180856]]
#
#  [[ 0.23156985  0.        ]
#   [ 0.08540047  0.21266341]]]

# %%
loc_ = loc.numpy()
ax = sns.kdeplot(x = loc_[:,0,0], y = loc_[:,0,1], shade=True, shade_lowest=False)
ax = sns.kdeplot(x = loc_[:,1,0], y = loc_[:,1,1], shade=True, shade_lowest=False)
ax = sns.kdeplot(x = loc_[:,2,0], y = loc_[:,2,1], shade=True, shade_lowest=False)
plt.title('KDE of loc draws');

# %% [markdown]
# # Numpyro working but sigma of one dimention only

# %%
data
# Out:
# array([[8.80444441e+01, 8.68018724e-01],
#        [8.02545498e+01, 8.57072925e-01],
#        [8.30077981e+01, 8.48769604e-01],
#        [8.10745809e+01, 7.63805554e-01],
#        [7.40498462e+01, 7.30005611e-01],
#        [7.33275360e+01, 6.96823518e-01],
#        [9.19608741e+01, 8.24651675e-01],
#        [8.18237287e+01, 8.18056094e-01],
#        [8.13839143e+01, 8.68034843e-01],
#        [6.72824745e+01, 6.50952778e-01],
#        [8.33483976e+01, 8.08127876e-01],
#        [7.59276809e+01, 8.59258174e-01],
#        [7.68781560e+01, 9.17165252e-01],
#        [8.55019046e+01, 7.94330047e-01],
#        [8.82287167e+01, 9.79717954e-01],
#        [8.06927770e+01, 8.10670298e-01],
#        [8.32692666e+01, 8.12381406e-01],
#        [8.30437679e+01, 9.81757544e-01],
#        [8.07868421e+01, 7.53526135e-01],
#        [9.61794468e+01, 9.56010292e-01],
#        [9.04040892e+01, 9.08352495e-01],
#        [5.30031942e+01, 7.34463207e-01],
#        [9.09692897e+01, 8.39430595e-01],
#        [8.42288478e+01, 7.92532298e-01],
#        [9.11119491e+01, 7.91304330e-01],
#        [5.42519433e+01, 1.64193061e-01],
#        [9.86616253e+01, 2.37267959e-01],
#        [6.91775154e+01, 1.61183617e-01],
#        [8.83540163e+01, 9.49820543e-02],
#        [6.86653736e+01, 2.34128042e-01],
#        [1.01283876e+02, 1.81967439e-01],
#        [7.82200251e+01, 3.11860010e-01],
#        [7.70868337e+01, 1.78331131e-01],
#        [7.35574318e+01, 1.96197300e-01],
#        [7.14260783e+01, 7.59832559e-02],
#        [7.81998668e+01, 6.77311502e-02],
#        [8.36782174e+01, 8.64718567e-02],
#        [8.63472894e+01, 3.17250508e-01],
#        [9.01593103e+01, 4.27965235e-01],
#        [7.74997328e+01, 2.43890056e-01],
#        [9.26596403e+01, 3.82308315e-01],
#        [8.60990380e+01, 2.33161193e-01],
#        [7.18028035e+01, 2.84958207e-01],
#        [8.58365846e+01, 2.65155256e-01],
#        [7.33293657e+01, 2.41944829e-01],
#        [9.20257940e+01, 5.07969961e-01],
#        [1.06816431e+02, 2.32870142e-01],
#        [8.58412879e+01, 3.00071133e-01],
#        [6.40957396e+01, 9.81043163e-02],
#        [7.55288702e+01, 3.45514748e-01],
#        [4.19518244e+01, 7.50913908e-01],
#        [3.02557954e+01, 5.78516192e-01],
#        [4.28413990e+01, 9.07313930e-01],
#        [3.55232732e+01, 7.58937316e-01],
#        [3.77948994e+01, 6.93939893e-01],
#        [3.85224585e+01, 7.98218353e-01],
#        [3.61890587e+01, 8.46277297e-01],
#        [3.94649935e+01, 6.45475137e-01],
#        [5.45289745e+01, 9.32187555e-01],
#        [4.64981504e+01, 7.41248038e-01],
#        [4.59403551e+01, 7.27866704e-01],
#        [4.98151938e+01, 7.92389567e-01],
#        [3.45883872e+01, 8.86425254e-01],
#        [3.65499667e+01, 8.17683125e-01],
#        [4.30023926e+01, 7.95386122e-01],
#        [4.69729253e+01, 8.07008436e-01],
#        [3.35773035e+01, 8.31679754e-01],
#        [4.28413779e+01, 8.07075315e-01],
#        [3.52371946e+01, 7.48865350e-01],
#        [4.22883535e+01, 8.43579709e-01],
#        [4.17973979e+01, 7.56782027e-01],
#        [4.49560584e+01, 6.98600022e-01],
#        [4.33121508e+01, 8.87434293e-01],
#        [4.62993517e+01, 7.59954057e-01],
#        [3.80610452e+01, 9.04750221e-01],
#        [3.54476439e+01, 1.63531857e-01],
#        [4.49998258e+01, 1.08806663e-01],
#        [3.68117362e+01, 1.63307728e-01],
#        [3.88217879e+01, 1.02447445e-01],
#        [3.65128079e+01, 2.72592911e-01],
#        [3.78857402e+01, 1.52499575e-01],
#        [3.90040288e+01, 1.35009057e-01],
#        [4.22258685e+01, 5.88627049e-02],
#        [4.03993448e+01, 4.56016442e-02],
#        [3.91249436e+01, 2.09098870e-02],
#        [4.99145146e+01, 1.81825072e-01],
#        [4.14522689e+01, 2.86254155e-01],
#        [4.35463961e+01, 2.08942449e-01],
#        [4.43098799e+01, 2.93084126e-01],
#        [3.67719917e+01, 1.04661991e-01],
#        [3.11861839e+01, 1.05537019e-01],
#        [4.19294845e+01, 1.58632572e-01],
#        [3.70890107e+01, 1.42118169e-01],
#        [4.57991823e+01, 3.13553426e-01],
#        [4.20592566e+01, 2.47610536e-01],
#        [2.86044188e+01, 2.49651128e-01],
#        [3.94009879e+01, 0.00000000e+00],
#        [4.39718305e+01, 1.98768741e-01],
#        [4.26452988e+01, 2.14287003e-01],
#        [4.70540891e+01, 3.10501609e-01]])

# %%
import jax.numpy as jnp
import numpyro
import funsor
import numpyro.distributions as dists
from numpyro.ops.indexing import Vindex
N, dim = data.shape
def model(K = 4 , data = data , weight = 0.5, dim = dim, N = N):
    cluster_proba = numpyro.sample('cluster_proba', dists.Dirichlet(weight * jnp.ones(K)))
    # Plate over components
    with numpyro.plate("plate1", K,dim):    
        sigma = numpyro.sample('sigma', dists.HalfCauchy(scale=10))  # Or adjust to [K, dim]            
        locs = numpyro.sample('locs', dists.MultivariateNormal(jnp.zeros(dim), 10 * jnp.eye(dim)))
    
    # Data plate
    with numpyro.plate('data', len(data)):
        assignment = numpyro.sample('assignment', dists.Categorical(probs=cluster_proba))
        sigma_expanded = Vindex(sigma)[assignment][..., None, None] * jnp.eye(dim)
        numpyro.sample('obs', dists.MultivariateNormal(Vindex(locs)[assignment], sigma_expanded), obs=data)

m.data_on_model = {'data':data, 'K':4}
rng_key = jax.random.PRNGKey(0)

num_warmup, num_samples = 1000, 5000

kernel = NUTS(model)
mcmc = MCMC(
    kernel,
    num_warmup=num_warmup,
    num_samples=num_samples,
)

mcmc.run(rng_key, data=data,K=3,dim=3)
mcmc.print_summary()
posterior_samples = mcmc.get_samples()
# Out:
# C:\Users\SSosa\AppData\Local\Temp\ipykernel_32868\536601723.py:32: FutureWarning: Some algorithms will automatically enumerate the discrete latent site assignment of your model. In the future, enumerated sites need to be marked with `infer={'enumerate': 'parallel'}`.
#   mcmc.run(rng_key, data=data,K=3,dim=3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\lax\lax.py:174, in _broadcast_shapes_uncached(*shapes)
#     173 try:
# --> 174   return _try_broadcast_shapes(*rank_promoted_shapes, name='broadcast_shapes')
#     175 except TypeError as err:
#     176   # Raise ValueError here for backward compatibility.
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\lax\lax.py:128, in _try_broadcast_shapes(name, *shapes)
#     127     else:
# --> 128       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     129                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     130 return tuple(result_shape)
#
# TypeError: broadcast_shapes got incompatible shapes for broadcasting: (1, 100, 2), (3, 1, 3).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\util.py:302, in cache.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     301   return f(*args, **kwargs)
# --> 302 return cached(config.trace_context() if trace_context_in_key else _ignore(),
#     303               *args, **kwargs)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\util.py:296, in cache.<locals>.wrap.<locals>.cached(_, *args, **kwargs)
#     294 @functools.lru_cache(max_size)
#     295 def cached(_, *args, **kwargs):
# --> 296   return f(*args, **kwargs)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\lax\lax.py:158, in _broadcast_shapes_cached(*shapes)
#     156 @cache()
#     157 def _broadcast_shapes_cached(*shapes: tuple[int, ...]) -> tuple[int, ...]:
# --> 158   return _broadcast_shapes_uncached(*shapes)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\lax\lax.py:177, in _broadcast_shapes_uncached(*shapes)
#     175 except TypeError as err:
#     176   # Raise ValueError here for backward compatibility.
# --> 177   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}") from err
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(100, 2), (3, 1, 3)]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\lax\lax.py:128, in _try_broadcast_shapes(name, *shapes)
#     127     else:
# --> 128       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     129                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     130 return tuple(result_shape)
#
# TypeError: broadcast_shapes got incompatible shapes for broadcasting: (1, 100, 2), (3, 1, 3).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 32
#      25 kernel = NUTS(model)
#      26 mcmc = MCMC(
#      27     kernel,
#      28     num_warmup=num_warmup,
#      29     num_samples=num_samples,
#      30 )
# ---> 32 mcmc.run(rng_key, data=data,K=3,dim=3)
#      33 mcmc.print_summary()
#      34 posterior_samples = mcmc.get_samples()
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:702, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     700 map_args = (rng_key, init_state, init_params)
#     701 if self.num_chains == 1:
# --> 702     states_flat, last_state = partial_map_fn(map_args)
#     703     states = jax.tree.map(lambda x: x[jnp.newaxis, ...], states_flat)
#     704 else:
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:465, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields, remove_sites)
#     463 # Check if _sample_fn is None, then we need to initialize the sampler.
#     464 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 465     new_init_state = self.sampler.init(
#     466         rng_key,
#     467         self.num_warmup,
#     468         init_params,
#     469         model_args=args,
#     470         model_kwargs=kwargs,
#     471     )
#     472     init_state = new_init_state if init_state is None else init_state
#     473 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:749, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     744 # vectorized
#     745 else:
#     746     rng_key, rng_key_init_model = jnp.swapaxes(
#     747         vmap(random.split)(rng_key), 0, 1
#     748     )
# --> 749 init_params = self._init_state(
#     750     rng_key_init_model, model_args, model_kwargs, init_params
#     751 )
#     752 if self._potential_fn and init_params is None:
#     753     raise ValueError(
#     754         "Valid value of `init_params` must be provided with `potential_fn`."
#     755     )
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:693, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     686 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     687     if self._model is not None:
#     688         (
#     689             new_init_params,
#     690             potential_fn,
#     691             postprocess_fn,
#     692             model_trace,
# --> 693         ) = initialize_model(
#     694             rng_key,
#     695             self._model,
#     696             dynamic_args=True,
#     697             init_strategy=self._init_strategy,
#     698             model_args=model_args,
#     699             model_kwargs=model_kwargs,
#     700             forward_mode_differentiation=self._forward_mode_differentiation,
#     701         )
#     702         if init_params is None:
#     703             init_params = new_init_params
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:750, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     748     init_strategy = _init_to_unconstrained_value(values=unconstrained_values)
#     749 prototype_params = transform_fn(inv_transforms, constrained_values, invert=True)
# --> 750 (init_params, pe, grad), is_valid = find_valid_initial_params(
#     751     rng_key,
#     752     substitute(
#     753         model,
#     754         data={
#     755             k: site["value"]
#     756             for k, site in model_trace.items()
#     757             if site["type"] in ["plate"]
#     758         },
#     759     ),
#     760     init_strategy=init_strategy,
#     761     enum=has_enumerate_support,
#     762     model_args=model_args,
#     763     model_kwargs=model_kwargs,
#     764     prototype_params=prototype_params,
#     765     forward_mode_differentiation=forward_mode_differentiation,
#     766     validate_grad=validate_grad,
#     767 )
#     769 if not_jax_tracer(is_valid):
#     770     if device_get(~jnp.all(is_valid)):
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:472, in find_valid_initial_params(rng_key, model, init_strategy, enum, model_args, model_kwargs, prototype_params, forward_mode_differentiation, validate_grad)
#     470 # Handle possible vectorization
#     471 if is_prng_key(rng_key):
# --> 472     (init_params, pe, z_grad), is_valid = _find_valid_params(
#     473         rng_key, exit_early=True
#     474     )
#     475 else:
#     476     (init_params, pe, z_grad), is_valid = lax.map(_find_valid_params, rng_key)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:458, in find_valid_initial_params.<locals>._find_valid_params(rng_key, exit_early)
#     454 init_state = (0, rng_key, (prototype_params, 0.0, prototype_grads), False)
#     455 if exit_early and not_jax_tracer(rng_key):
#     456     # Early return if valid params found. This is only helpful for single chain,
#     457     # where we can avoid compiling body_fn in while_loop.
# --> 458     _, _, (init_params, pe, z_grad), is_valid = init_state = body_fn(init_state)
#     459     if not_jax_tracer(is_valid):
#     460         if device_get(is_valid):
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:442, in find_valid_initial_params.<locals>.body_fn(state)
#     440     z_grad = jacfwd(potential_fn)(params)
#     441 else:
# --> 442     pe, z_grad = value_and_grad(potential_fn)(params)
#     443 z_grad_flat = ravel_pytree(z_grad)[0]
#     444 is_valid = jnp.isfinite(pe) & jnp.all(jnp.isfinite(z_grad_flat))
#
#     [... skipping hidden 15 frame]
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:324, in potential_energy(model, model_args, model_kwargs, params, enum)
#     320 substituted_model = substitute(
#     321     model, substitute_fn=partial(_unconstrain_reparam, params)
#     322 )
#     323 # no param is needed for log_density computation because we already substitute
# --> 324 log_joint, model_trace = log_density_(
#     325     substituted_model, model_args, model_kwargs, {}
#     326 )
#     327 return -log_joint
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\contrib\funsor\infer_util.py:322, in log_density(model, model_args, model_kwargs, params)
#     301 def log_density(model, model_args, model_kwargs, params):
#     302     """
#     303     Similar to :func:`numpyro.infer.util.log_density` but works for models
#     304     with discrete latent variables. Internally, this uses :mod:`funsor`
#    (...)
#     320     :return: log of joint density and a corresponding model trace
#     321     """
# --> 322     result, model_trace, _ = _enum_log_density(
#     323         model,
#     324         model_args,
#     325         model_kwargs,
#     326         params,
#     327         funsor.ops.logaddexp,
#     328         funsor.ops.add,
#     329     )
#     330     return result.data, model_trace
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\contrib\funsor\infer_util.py:217, in _enum_log_density(model, model_args, model_kwargs, params, sum_op, prod_op)
#     215     log_prob = site["fn"].log_prob(value, intermediates)
#     216 else:
# --> 217     log_prob = site["fn"].log_prob(value)
#     219 if (scale is not None) and (not is_identically_one(scale)):
#     220     log_prob = scale * log_prob
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\distributions\distribution.py:735, in ExpandedDistribution.log_prob(self, value, intermediates)
#     729 def log_prob(self, value, intermediates=None):
#     730     # TODO: utilize `intermediates`
#     731     shape = lax.broadcast_shapes(
#     732         self.batch_shape,
#     733         jnp.shape(value)[: max(jnp.ndim(value) - self.event_dim, 0)],
#     734     )
# --> 735     log_prob = self.base_dist.log_prob(value)
#     736     return jnp.broadcast_to(log_prob, shape)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\distributions\util.py:764, in validate_sample.<locals>.wrapper(self, *args, **kwargs)
#     763 def wrapper(self, *args, **kwargs):
# --> 764     log_prob = log_prob_fn(self, *args, **kwargs)
#     765     if self._validate_args:
#     766         value = kwargs["value"] if "value" in kwargs else args[0]
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\distributions\continuous.py:1633, in MultivariateNormal.log_prob(self, value)
#    1631 @validate_sample
#    1632 def log_prob(self, value):
# -> 1633     M = _batch_mahalanobis(self.scale_tril, value - self.loc)
#    1634     half_log_det = tri_logabsdet(self.scale_tril)
#    1635     normalize_term = half_log_det + 0.5 * self.scale_tril.shape[-1] * jnp.log(
#    1636         2 * jnp.pi
#    1637     )
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\numpy\array_methods.py:1061, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1060 def op(self, *args):
# -> 1061   return getattr(self.aval, f"_{name}")(self, *args)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\numpy\array_methods.py:578, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     576 args = (other, self) if swap else (self, other)
#     577 if isinstance(other, _accepted_binop_types):
# --> 578   return binary_op(*args)
#     579 # Note: don't use isinstance here, because we don't want to raise for
#     580 # subclasses, e.g. NamedTuple objects that may override operators.
#     581 if type(other) in _rejected_binop_types:
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\numpy\ufunc_api.py:179, in ufunc.__call__(self, out, where, *args)
#     177   raise NotImplementedError(f"where argument of {self}")
#     178 call = self.__static_props['call'] or self._call_vectorized
# --> 179 return call(*args)
#
#     [... skipping hidden 13 frame]
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\numpy\ufuncs.py:1544, in subtract(x, y)
#    1517 @binary_ufunc(identity=None, at=_subtract_at)
#    1518 def subtract(x: ArrayLike, y: ArrayLike, /) -> Array:
#    1519   """Subtract two arrays element-wise.
#    1520
#    1521   JAX implementation of :obj:`numpy.subtract`. This is a universal function,
#    (...)
#    1542     Array([-10,  -9,  -8,  -7], dtype=int32)
#    1543   """
# -> 1544   return lax.sub(*promote_args("subtract", x, y))
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\numpy\util.py:193, in promote_args(fun_name, *args)
#     191 _check_no_float0s(fun_name, *args)
#     192 check_for_prngkeys(fun_name, *args)
# --> 193 return promote_shapes(fun_name, *promote_dtypes(*args))
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\numpy\util.py:58, in promote_shapes(fun_name, *args)
#      56 if config.numpy_rank_promotion.value != "allow":
#      57   _rank_promotion_warning_or_error(fun_name, shapes)
# ---> 58 result_rank = len(lax.broadcast_shapes(*shapes))
#      59 return [lax.broadcast_to_rank(arg, result_rank) for arg in args]
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\jax\_src\lax\lax.py:177, in _broadcast_shapes_uncached(*shapes)
#     174   return _try_broadcast_shapes(*rank_promoted_shapes, name='broadcast_shapes')
#     175 except TypeError as err:
#     176   # Raise ValueError here for backward compatibility.
# --> 177   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}") from err
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(100, 2), (3, 1, 3)]

# %%
def model(K,dim,data=None):
    cluster_proba = numpyro.sample('cluster_proba',dist.Dirichlet(0.5 * jnp.ones(K)))
    with numpyro.plate('components', K):
        locs=numpyro.sample('locs',dist.MultivariateNormal(jnp.zeros(dim),10*jnp.eye(dim))) 
        sigma = numpyro.sample('sigma', dist.HalfCauchy(scale=10))
    with numpyro.plate('data', len(data)):
        assignment = numpyro.sample('assignment', dist.Categorical(cluster_proba),infer={"enumerate": "parallel"}) 
        numpyro.sample('obs', dist.MultivariateNormal(locs[assignment,:][1], sigma[assignment][1]*jnp.eye(dim)), obs=data)

rng_key = jax.random.PRNGKey(0)

num_warmup, num_samples = 1000, 5000

kernel = NUTS(model)
mcmc = MCMC(
    kernel,
    num_warmup=num_warmup,
    num_samples=num_samples,
)
mcmc.run(rng_key, data=data,K=3,dim=3)
mcmc.print_summary()
posterior_samples = mcmc.get_samples()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 20
#      14 kernel = NUTS(model)
#      15 mcmc = MCMC(
#      16     kernel,
#      17     num_warmup=num_warmup,
#      18     num_samples=num_samples,
#      19 )
# ---> 20 mcmc.run(rng_key, data=data,K=3,dim=3)
#      21 mcmc.print_summary()
#      22 posterior_samples = mcmc.get_samples()
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:702, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     700 map_args = (rng_key, init_state, init_params)
#     701 if self.num_chains == 1:
# --> 702     states_flat, last_state = partial_map_fn(map_args)
#     703     states = jax.tree.map(lambda x: x[jnp.newaxis, ...], states_flat)
#     704 else:
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:465, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields, remove_sites)
#     463 # Check if _sample_fn is None, then we need to initialize the sampler.
#     464 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 465     new_init_state = self.sampler.init(
#     466         rng_key,
#     467         self.num_warmup,
#     468         init_params,
#     469         model_args=args,
#     470         model_kwargs=kwargs,
#     471     )
#     472     init_state = new_init_state if init_state is None else init_state
#     473 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:749, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     744 # vectorized
#     745 else:
#     746     rng_key, rng_key_init_model = jnp.swapaxes(
#     747         vmap(random.split)(rng_key), 0, 1
#     748     )
# --> 749 init_params = self._init_state(
#     750     rng_key_init_model, model_args, model_kwargs, init_params
#     751 )
#     752 if self._potential_fn and init_params is None:
#     753     raise ValueError(
#     754         "Valid value of `init_params` must be provided with `potential_fn`."
#     755     )
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:693, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     686 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     687     if self._model is not None:
#     688         (
#     689             new_init_params,
#     690             potential_fn,
#     691             postprocess_fn,
#     692             model_trace,
# --> 693         ) = initialize_model(
#     694             rng_key,
#     695             self._model,
#     696             dynamic_args=True,
#     697             init_strategy=self._init_strategy,
#     698             model_args=model_args,
#     699             model_kwargs=model_kwargs,
#     700             forward_mode_differentiation=self._forward_mode_differentiation,
#     701         )
#     702         if init_params is None:
#     703             init_params = new_init_params
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:688, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     678 model_kwargs = {} if model_kwargs is None else model_kwargs
#     679 substituted_model = substitute(
#     680     seed(model, rng_key if is_prng_key(rng_key) else rng_key[0]),
#     681     substitute_fn=init_strategy,
#     682 )
#     683 (
#     684     inv_transforms,
#     685     replay_model,
#     686     has_enumerate_support,
#     687     model_trace,
# --> 688 ) = _get_model_transforms(substituted_model, model_args, model_kwargs)
#     690 for name, site in model_trace.items():
#     691     if (
#     692         site["type"] == "sample"
#     693         and isinstance(site["fn"], dist.Delta)
#     694         and not site["is_observed"]
#     695     ):
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:482, in _get_model_transforms(model, model_args, model_kwargs)
#     480 def _get_model_transforms(model, model_args=(), model_kwargs=None):
#     481     model_kwargs = {} if model_kwargs is None else model_kwargs
# --> 482     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#     483     inv_transforms = {}
#     484     # model code may need to be replayed in the presence of deterministic sites
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\handlers.py:191, in trace.get_trace(self, *args, **kwargs)
#     183 def get_trace(self, *args, **kwargs) -> OrderedDict[str, Message]:
#     184     """
#     185     Run the wrapped callable and return the recorded trace.
#     186
#    (...)
#     189     :return: `OrderedDict` containing the execution trace.
#     190     """
# --> 191     self(*args, **kwargs)
#     192     return self.trace
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# Cell In[25], line 2, in model(K, dim, data)
#       1 def model(K,dim,data=None):
# ----> 2     cluster_proba = numpyro.sample('cluster_proba',dist.Dirichlet(0.5 * jnp.ones(K)))
#       3     with numpyro.plate('components', K):
#       4         locs=numpyro.sample('locs',dist.MultivariateNormal(jnp.zeros(dim),10*jnp.eye(dim)))
#
# AttributeError: type object 'UnifiedDist' has no attribute 'Dirichlet'

# %%
import numpyro.distributions as dists
from numpyro.ops.indexing import Vindex
def model(K, data=None, weight = 1):
    N, dim = data.shape
    cluster_proba = numpyro.sample('cluster_proba', dists.Dirichlet(weight * jnp.ones(K)))
    

    with numpyro.plate('components', K, dim= -1 ):
        locs = numpyro.sample('locs', dists.MultivariateNormal(jnp.zeros(dim), 10 * jnp.eye(dim)))
        sigma = numpyro.sample('sigma', dists.HalfCauchy(scale=10)) # TODO: Need to set up a different sigma for each axes.!!!!!!!!!!!!!!!!

    
    with numpyro.plate('data', N):
        assignment = numpyro.sample('assignment', dists.Categorical(cluster_proba), infer={"enumerate": "parallel"})
        
        # Correctly broadcast sigma to create covariance matrices
        sigma_expanded = Vindex(sigma)[assignment][..., None, None] * jnp.eye(dim)
        
        numpyro.sample('obs',  dists.MultivariateNormal(Vindex(locs)[assignment], sigma_expanded), obs=data)
    #print( assignment.shape)
    

    #sigma = bee.dist.exponential(1, shape = (1,))
    #alpha = bee.dist.normal(0,1, name = 'alpha', shape = (1,))
    #beta1 = bee.dist.normal(0,10, name = 'N vistis', shape = (1,))
    #beta2 = bee.dist.normal(0,10, name = 'Proportion of associations', shape = (1,))
    #mu = alpha + beta1 * data[:,0] + beta2 * data[:, 1]
    #print(sigma.shape)
    #print(alpha.shape)
    #print(beta1.shape)
    #print(beta2.shape)
    #print(mu.shape)
    #numpyro.sample('test', dists.Normal(mu, sigma), obs=assignment)

m.data_on_model = {'data':data, 'K':4}
m.run(model, num_warmup=1000, num_samples=1000, seed= 5)
m.sampler.print_summary() #p_real = [0.50, 0.10, 0.30, 0.10],
# Out:
# sample: 100%|██████████| 2000/2000 [00:05<00:00, 398.37it/s, 7 steps of size 5.07e-01. acc. prob=0.88]
#                       mean       std    median      5.0%     95.0%     n_eff     r_hat
# cluster_proba[0]      0.01      0.01      0.01      0.00      0.02   1341.28      1.00
# cluster_proba[1]      0.97      0.02      0.98      0.95      0.99   1846.76      1.00
# cluster_proba[2]      0.01      0.01      0.01      0.00      0.02   1290.61      1.00
# cluster_proba[3]      0.01      0.01      0.01      0.00      0.02   1264.90      1.00
#        locs[0,0]      0.12      3.08      0.23     -5.70      4.76   1676.51      1.00
#        locs[0,1]     -0.04      3.33     -0.00     -5.19      5.59   1104.95      1.00
#        locs[1,0]     43.91      2.30     43.98     39.70     47.18    912.48      1.00
#        locs[1,1]      0.28      1.77      0.22     -2.60      3.08   1500.82      1.00
#        locs[2,0]      0.17      3.11      0.20     -4.78      5.33   1295.92      1.00
#        locs[2,1]     -0.06      3.03     -0.04     -5.29      4.51   1693.74      1.00
#        locs[3,0]      0.04      3.07      0.06     -5.35      4.57   1682.11      1.00
#        locs[3,1]      0.05      3.06      0.08     -5.10      4.99   1945.57      1.00
#         sigma[0]     34.59    167.34      9.72      0.01     57.71    913.85      1.00
#         sigma[1]    394.10     57.12    387.15    301.30    482.28    922.08      1.00
#         sigma[2]     77.05    956.81      9.73      0.03     59.49    959.34      1.00
#         sigma[3]     72.59    378.74     10.80      0.00     79.85    785.50      1.00
#
# Number of divergences: 0

# %%
K=4
posterior_samples = m.sampler.get_samples()
predictive =Predictive(model, posterior_samples)
predictions = predictive(jax.random.PRNGKey(1), data=data, K=K)
pred_clusters = predictions['assignment']
#cluster_probs = jnp.mean(jax.nn.one_hot(predicted_assignments, K), axis=0)
cluster_probs = vmap(lambda x: cluster_proba(x), in_axes = 0)(pred_clusters.T)

# Get most likely cluster for each point
final_assignments = jnp.argmax(cluster_probs, axis=1)
final_assignments
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       5 pred_clusters = predictions['assignment']
#       6 #cluster_probs = jnp.mean(jax.nn.one_hot(predicted_assignments, K), axis=0)
# ----> 7 cluster_probs = vmap(lambda x: cluster_proba(x), in_axes = 0)(pred_clusters.T)
#       9 # Get most likely cluster for each point
#      10 final_assignments = jnp.argmax(cluster_probs, axis=1)
#
#     [... skipping hidden 6 frame]
#
# Cell In[20], line 7, in <lambda>(x)
#       5 pred_clusters = predictions['assignment']
#       6 #cluster_probs = jnp.mean(jax.nn.one_hot(predicted_assignments, K), axis=0)
# ----> 7 cluster_probs = vmap(lambda x: cluster_proba(x), in_axes = 0)(pred_clusters.T)
#       9 # Get most likely cluster for each point
#      10 final_assignments = jnp.argmax(cluster_probs, axis=1)
#
# NameError: name 'cluster_proba' is not defined

# %%
#cluster_probs = jnp.mean(jax.nn.one_hot(predicted_assignments, K), axis=0)
cluster_probs = vmap(lambda x: cat_probs(x), in_axes = 0)(pred_clusters.T)

# Get most likely cluster for each point
final_assignments = jnp.argmax(cluster_probs, axis=1)
final_assignments

# %%
import matplotlib.pyplot as plt
def cat_probs(tmp, max_category = 4):
    counts = jnp.bincount(tmp, length=max_category)  # Count occurrences of each category
    percentages = (counts / tmp.size) * 100
    return percentages

def analyze(sampler, data,  K=4):
    # Get posterior samples
    posterior_samples = sampler.get_samples()

    # Use Predictive to get cluster assignments
    predictive = Predictive(model, posterior_samples)
    predictions = predictive(jax.random.PRNGKey(1), data=data, K=K)
    predicted_assignments = predictions['assignment']

    # Calculate cluster probabilities
    #cluster_probs = jnp.mean(jax.nn.one_hot(predicted_assignments, K), axis=0)
    cluster_probs = vmap(lambda x: cat_probs(x), in_axes = 0)(predicted_assignments.T)
    
    # Get most likely cluster for each point
    final_assignments = jnp.argmax(cluster_probs, axis=1)

    plot_synthetic_data(data, final_assignments)
    
    # Calculate uncertainty
    assignment_uncertainty = 1 - jnp.max(cluster_probs, axis=1)
    print(cluster_probs)
    print("\nMean assignment uncertainty:", jnp.mean(assignment_uncertainty))

analyze(m.sampler, data, K=4)
# Out:
# [[25.1 26.2 20.7 28. ]
#  [22.3 28.1 21.8 27.8]
#  [23.5 25.9 19.1 31.5]
#  [21.4 26.2 25.  27.4]
#  [25.  24.3 21.7 29. ]
#  [24.2 26.7 20.9 28.2]
#  [21.3 26.  22.5 30.2]
#  [24.3 24.4 23.5 27.8]
#  [23.  27.3 22.7 27. ]
#  [23.8 27.2 22.  27. ]
#  [23.4 26.6 20.7 29.3]
#  [21.8 26.  23.7 28.5]
#  [23.5 26.2 20.4 29.9]
#  [22.4 24.3 21.3 32. ]
#  [25.4 24.8 19.5 30.3]
#  [21.9 25.8 21.3 31. ]
#  [24.1 25.8 24.  26.1]
#  [23.7 26.6 19.5 30.2]
#  [23.3 29.5 21.3 25.9]
#  [23.3 25.9 20.4 30.4]
#  [23.9 26.6 20.1 29.4]
#  [22.7 26.8 21.2 29.3]
#  [23.4 27.2 20.6 28.8]
#  [24.2 25.  21.5 29.3]
#  [23.6 26.5 22.  27.9]
#  [25.7 25.  20.2 29.1]
#  [22.1 26.9 21.5 29.5]
#  [22.5 30.  20.1 27.4]
#  [24.5 28.1 20.5 26.9]
#  [25.2 26.2 21.1 27.5]
#  [23.4 27.3 21.3 28. ]
#  [23.4 25.8 20.1 30.7]
#  [24.6 25.2 22.  28.2]
#  [22.4 25.3 23.4 28.9]
#  [22.7 25.3 19.4 32.6]
#  [24.8 27.7 19.5 28. ]
#  [24.1 25.  22.2 28.7]
#  [23.5 26.8 21.7 28. ]
#  [24.5 27.4 20.8 27.3]
#  [22.4 27.  23.4 27.2]
#  [23.2 25.7 21.9 29.2]
#  [22.9 26.9 23.1 27.1]
#  [23.8 26.6 22.  27.6]
#  [25.  26.6 22.  26.4]
#  [24.8 25.6 19.6 30. ]
#  [24.4 26.9 19.3 29.4]
#  [23.9 22.8 21.  32.3]
#  [24.  29.4 20.5 26.1]
#  [24.7 25.4 20.1 29.8]
#  [25.4 27.9 20.1 26.6]
#  [21.9 26.4 22.  29.7]
#  [24.3 26.8 21.4 27.5]
#  [25.3 27.  19.5 28.2]
#  [26.3 26.1 20.2 27.4]
#  [26.2 25.2 22.1 26.5]
#  [24.2 21.3 23.3 31.2]
#  [23.8 28.4 20.8 27. ]
#  [23.9 27.2 20.9 28. ]
#  [23.2 25.3 19.8 31.7]
#  [24.1 24.5 22.5 28.9]
#  [25.6 27.  19.7 27.7]
#  [25.1 26.7 19.2 29. ]
#  [24.1 26.9 20.  29. ]
#  [25.3 24.8 20.4 29.5]
#  [22.6 27.1 21.8 28.5]
#  [25.6 25.6 19.2 29.6]
#  [25.5 25.9 21.9 26.7]
#  [22.3 25.8 22.9 29. ]
#  [24.9 26.8 20.5 27.8]
#  [23.4 27.2 19.7 29.7]
#  [22.6 27.6 19.2 30.6]
#  [23.7 25.  23.6 27.7]
#  [25.8 24.2 21.4 28.6]
#  [23.8 24.2 23.  29. ]
#  [23.2 25.4 22.4 29. ]
#  [26.9 25.9 19.4 27.8]
#  [23.7 24.7 22.2 29.4]
#  [26.2 24.8 21.3 27.7]
#  [21.5 28.3 22.4 27.8]
#  [22.7 25.8 21.  30.5]
#  [22.9 24.7 22.3 30.1]
#  [24.7 25.4 20.4 29.5]
#  [24.3 26.3 20.3 29.1]
#  [22.1 24.5 22.5 30.9]
#  [25.6 26.7 20.7 27. ]
#  [24.6 25.2 21.2 29. ]
#  [25.  24.8 21.8 28.4]
#  [25.2 24.5 21.4 28.9]
#  [22.2 32.1 18.6 27.1]
#  [24.5 25.1 20.9 29.5]
#  [22.4 27.5 19.  31.1]
#  [24.  26.6 22.2 27.2]
#  [24.7 23.8 21.7 29.8]
#  [24.1 25.4 21.9 28.6]
#  [23.5 26.4 20.4 29.7]
#  [23.3 26.3 21.1 29.3]
#  [22.8 27.4 21.3 28.5]
#  [25.  26.1 20.6 28.3]
#  [22.5 28.8 18.6 30.1]
#  [26.2 25.6 21.1 27.1]]
#
# Mean assignment uncertainty: -27.945999999999998

# %% [markdown]
# # Numpyro without plates

# %%
import numpyro.distributions as dists
from numpyro.ops.indexing import Vindex
def model(K, data=None, weight = 1):
    N, dim = data.shape
    cluster_proba = numpyro.sample('cluster_proba', dists.Dirichlet(weight * jnp.ones(K)))
    
    locs = numpyro.sample('locs', dists.MultivariateNormal(jnp.zeros(dim), 10 * jnp.eye(dim)).expand([K,dim]))
    sigma = numpyro.sample('sigma', dists.HalfCauchy(scale=10).expand([K, dim])) # TODO: Need to set up a different sigma for each axes.!!!!!!!!!!!!!!!!

    assignment = numpyro.sample('assignment', dists.Categorical(cluster_proba).expand([N]), infer={"enumerate": "parallel"})
        
    # Correctly broadcast sigma to create covariance matrices
    sigma_expanded = Vindex(sigma)[assignment][..., None, None] * jnp.eye(dim)
        
    numpyro.sample('obs',  dists.MultivariateNormal(Vindex(locs)[assignment], sigma_expanded), obs=data)

m.data_on_model = {'data':data, 'K':4}
m.run(model, num_warmup=1000, num_samples=1000, seed= 5)
m.sampler.print_summary() #p_real = [0.50, 0.10, 0.30, 0.10],
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 18
#      15     numpyro.sample('obs',  dists.MultivariateNormal(Vindex(locs)[assignment], sigma_expanded), obs=data)
#      17 m.data_on_model = {'data':data, 'K':4}
# ---> 18 m.run(model, num_warmup=1000, num_samples=1000, seed= 5)
#      19 m.sampler.print_summary() #p_real = [0.50, 0.10, 0.30, 0.10],
#
# File g:\OneDrive\Travail\Max Planck\Projects\BI\bi\main.py:139, in bi.run(self, model, potential_fn, kinetic_fn, step_size, inverse_mass_matrix, adapt_step_size, adapt_mass_matrix, dense_mass, target_accept_prob, trajectory_length, max_tree_depth, init_strategy, find_heuristic_step_size, forward_mode_differentiation, regularize_mass_matrix, num_warmup, num_samples, num_chains, thinning, postprocess_fn, chain_method, progress_bar, jit_model_args, seed)
#     113     self.data_on_model = self.pd_to_jax(self.model)
#     115 self.sampler = MCMC(NUTS(self.model,
#     116                         potential_fn=potential_fn,
#     117                         kinetic_fn=kinetic_fn,
#    (...)
#     136                         progress_bar=progress_bar,
#     137                         jit_model_args=jit_model_args)
# --> 139 self.sampler.run(jax.random.PRNGKey(seed), **self.data_on_model)
#     140 self.posteriors = self.sampler.get_samples()
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:702, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     700 map_args = (rng_key, init_state, init_params)
#     701 if self.num_chains == 1:
# --> 702     states_flat, last_state = partial_map_fn(map_args)
#     703     states = jax.tree.map(lambda x: x[jnp.newaxis, ...], states_flat)
#     704 else:
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:465, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields, remove_sites)
#     463 # Check if _sample_fn is None, then we need to initialize the sampler.
#     464 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 465     new_init_state = self.sampler.init(
#     466         rng_key,
#     467         self.num_warmup,
#     468         init_params,
#     469         model_args=args,
#     470         model_kwargs=kwargs,
#     471     )
#     472     init_state = new_init_state if init_state is None else init_state
#     473 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:749, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     744 # vectorized
#     745 else:
#     746     rng_key, rng_key_init_model = jnp.swapaxes(
#     747         vmap(random.split)(rng_key), 0, 1
#     748     )
# --> 749 init_params = self._init_state(
#     750     rng_key_init_model, model_args, model_kwargs, init_params
#     751 )
#     752 if self._potential_fn and init_params is None:
#     753     raise ValueError(
#     754         "Valid value of `init_params` must be provided with `potential_fn`."
#     755     )
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:693, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     686 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     687     if self._model is not None:
#     688         (
#     689             new_init_params,
#     690             potential_fn,
#     691             postprocess_fn,
#     692             model_trace,
# --> 693         ) = initialize_model(
#     694             rng_key,
#     695             self._model,
#     696             dynamic_args=True,
#     697             init_strategy=self._init_strategy,
#     698             model_args=model_args,
#     699             model_kwargs=model_kwargs,
#     700             forward_mode_differentiation=self._forward_mode_differentiation,
#     701         )
#     702         if init_params is None:
#     703             init_params = new_init_params
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:727, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     725     if not isinstance(model, enum):
#     726         max_plate_nesting = _guess_max_plate_nesting(model_trace)
# --> 727         _validate_model(model_trace, plate_warning="error")
#     728         model = enum(config_enumerate(model), -max_plate_nesting - 1)
#     729 else:
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\util.py:594, in _validate_model(model_trace, plate_warning)
#     587 message = (
#     588     f"Missing a plate statement for batch dimension {dim}"
#     589     f" at site '{name}'. You can use `numpyro.util.format_shapes`"
#     590     " utility to check shapes at all sites of your model."
#     591 )
#     593 if plate_warning == "error":
# --> 594     raise ValueError(message)
#     595 elif plate_warning == "strict" or (len(plate_dims) > 0):
#     596     warnings.warn(message, stacklevel=find_stack_level())
#
# ValueError: Missing a plate statement for batch dimension -1 at site 'locs'. You can use `numpyro.util.format_shapes` utility to check shapes at all sites of your model.

# %% [markdown]
# Dear All,
# Up to my learning journey I manage to run my models without plate formulation by setting up parameters shapes but I know struggling with the GMM algorithm. I have multiples questions regarding plates in numpyro.
# 1. First, the plate version described in the following link is working : XXXX. But the sigma parameter is of shape 1 while it should be of shape of the number of features. How can I set-up this?
# 2. I tryed to run build the same model without plate formulation but it doesn't work despite the fact that my parameters have the correct shape as I use the same process to generate the data. Di d I miss something or do inferences be done without plate? This is the model : XXXX
# 3.
#
#
#
# I am trying to run the GMM algorithm.  While, I am not able to run the GMM algorithm with the plate formulation. I have tried to follow the example in the following link:

# %% [markdown]
# # Dirichlet Process Mixture Models in Pyro¶aa

# %%
import jax
import jax.numpy as jnp
import numpyro
import numpyro.distributions as dist
from numpyro import handlers
from numpyro.infer import MCMC, NUTS

def model(data):
    # Hyperparameters
    alpha = 1.0  # Concentration parameter for the Dirichlet Process
    K = 10       # Maximum number of components

    # Stick-breaking process to generate weights
    beta = numpyro.sample('beta', dist.Beta(1., alpha, shape=(K - 1,)))
    weights = jnp.concatenate([beta, jnp.array([1.0])])
    weights = jnp.cumprod(1.0 - weights) * weights

    # Component means and covariances
    means = numpyro.sample('means', dist.Normal(0., 1., shape=(K,)))
    covariances = numpyro.sample('covariances', dist.InverseGamma(1., 1., shape=(K,)))

    # Assignments
    assignments = numpyro.sample('assignments', dist.Categorical(weights, shape=(data.shape[0],)))

    # Observations
    with numpyro.plate('data', data.shape[0]):
        numpyro.sample('obs', dist.MultivariateNormal(means[assignments], covariances[assignments]), obs=data)

# Example usage
data = jnp.array([[1.0, 2.0], [1.5, 2.5], [3.0, 4.0]])  # Replace with your data
nuts_kernel = NUTS(model)
mcmc = MCMC(nuts_kernel, num_samples=1000, num_warmup=200)
mcmc.run(jax.random.PRNGKey(0), data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 33
#      31 nuts_kernel = NUTS(model)
#      32 mcmc = MCMC(nuts_kernel, num_samples=1000, num_warmup=200)
# ---> 33 mcmc.run(jax.random.PRNGKey(0), data)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:702, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     700 map_args = (rng_key, init_state, init_params)
#     701 if self.num_chains == 1:
# --> 702     states_flat, last_state = partial_map_fn(map_args)
#     703     states = jax.tree.map(lambda x: x[jnp.newaxis, ...], states_flat)
#     704 else:
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\mcmc.py:465, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields, remove_sites)
#     463 # Check if _sample_fn is None, then we need to initialize the sampler.
#     464 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 465     new_init_state = self.sampler.init(
#     466         rng_key,
#     467         self.num_warmup,
#     468         init_params,
#     469         model_args=args,
#     470         model_kwargs=kwargs,
#     471     )
#     472     init_state = new_init_state if init_state is None else init_state
#     473 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:749, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     744 # vectorized
#     745 else:
#     746     rng_key, rng_key_init_model = jnp.swapaxes(
#     747         vmap(random.split)(rng_key), 0, 1
#     748     )
# --> 749 init_params = self._init_state(
#     750     rng_key_init_model, model_args, model_kwargs, init_params
#     751 )
#     752 if self._potential_fn and init_params is None:
#     753     raise ValueError(
#     754         "Valid value of `init_params` must be provided with `potential_fn`."
#     755     )
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\hmc.py:693, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     686 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     687     if self._model is not None:
#     688         (
#     689             new_init_params,
#     690             potential_fn,
#     691             postprocess_fn,
#     692             model_trace,
# --> 693         ) = initialize_model(
#     694             rng_key,
#     695             self._model,
#     696             dynamic_args=True,
#     697             init_strategy=self._init_strategy,
#     698             model_args=model_args,
#     699             model_kwargs=model_kwargs,
#     700             forward_mode_differentiation=self._forward_mode_differentiation,
#     701         )
#     702         if init_params is None:
#     703             init_params = new_init_params
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:688, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     678 model_kwargs = {} if model_kwargs is None else model_kwargs
#     679 substituted_model = substitute(
#     680     seed(model, rng_key if is_prng_key(rng_key) else rng_key[0]),
#     681     substitute_fn=init_strategy,
#     682 )
#     683 (
#     684     inv_transforms,
#     685     replay_model,
#     686     has_enumerate_support,
#     687     model_trace,
# --> 688 ) = _get_model_transforms(substituted_model, model_args, model_kwargs)
#     690 for name, site in model_trace.items():
#     691     if (
#     692         site["type"] == "sample"
#     693         and isinstance(site["fn"], dist.Delta)
#     694         and not site["is_observed"]
#     695     ):
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\infer\util.py:482, in _get_model_transforms(model, model_args, model_kwargs)
#     480 def _get_model_transforms(model, model_args=(), model_kwargs=None):
#     481     model_kwargs = {} if model_kwargs is None else model_kwargs
# --> 482     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#     483     inv_transforms = {}
#     484     # model code may need to be replayed in the presence of deterministic sites
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\handlers.py:191, in trace.get_trace(self, *args, **kwargs)
#     183 def get_trace(self, *args, **kwargs) -> OrderedDict[str, Message]:
#     184     """
#     185     Run the wrapped callable and return the recorded trace.
#     186
#    (...)
#     189     :return: `OrderedDict` containing the execution trace.
#     190     """
# --> 191     self(*args, **kwargs)
#     192     return self.trace
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# Cell In[42], line 14, in model(data)
#      11 K = 10       # Maximum number of components
#      13 # Stick-breaking process to generate weights
# ---> 14 beta = numpyro.sample('beta', dist.Beta(1., alpha, shape=(K - 1,)))
#      15 weights = jnp.concatenate([beta, jnp.array([1.0])])
#      16 weights = jnp.cumprod(1.0 - weights) * weights
#
# File c:\Users\SSosa\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpyro\distributions\distribution.py:101, in DistributionMeta.__call__(cls, *args, **kwargs)
#      99     if result is not None:
#     100         return result
# --> 101 return super().__call__(*args, **kwargs)
#
# TypeError: Beta.__init__() got an unexpected keyword argument 'shape'
