# %%
from BI import bi
m = bi(platform='cpu')
# Out:
# jax.local_device_count 32

# %%
import jax.numpy as jnp
def diag_pre_multiply(v, m):
    """Dot product of a diagonal matrix with a matrix.
    Args:
        v (1D jax array): Vector of diagonal elements.
        m (2D jax array): Matrix to be multiplied.
    Returns:
        2D jax array: Dot product of a diagonal matrix with a matrix.
    """
    return jnp.matmul(jnp.diag(v), m)

def random_centered(sigma, cor_mat, offset_mat):
    """Generate the centered matrix of random factors 

    Args:
        sigma (vector): Prior, vector of length N
        cor_mat (2D array): correlation matrix, cholesky_factor_corr of dim N, N
        offset_mat (2D array): matrix of offsets, matrix of dim N*k

    Returns:
        _type_: 2D array
    """
    return jnp.dot(diag_pre_multiply(sigma, cor_mat), offset_mat)

# %%
ni = 20
K = 4
Sigma = m.dist.exponential(1, shape = ( ni ,) , sample = True)
L = m.dist.lkj_cholesky (2, sample = True)
Z = m.dist.normal(0 , 1 , shape = ( ni , K ), sample = True )
alpha = random_centered( Sigma , L , Z )

# %%
diag_pre_multiply(Sigma , L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 diag_pre_multiply(Sigma , L)
#
# Cell In[12], line 10, in diag_pre_multiply(v, m)
#       2 def diag_pre_multiply(v, m):
#       3     """Dot product of a diagonal matrix with a matrix.
#       4     Args:
#       5         v (1D jax array): Vector of diagonal elements.
#    (...)
#       8         2D jax array: Dot product of a diagonal matrix with a matrix.
#       9     """
# ---> 10     return jnp.matmul(jnp.diag(v), m)
#
#     [... skipping hidden 14 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/numpy/tensor_contractions.py:243, in matmul(a, b, precision, preferred_element_type)
#     241 a = lax.squeeze(a, tuple(a_squeeze))
#     242 b = lax.squeeze(b, tuple(b_squeeze))
# --> 243 out = lax.dot_general(
#     244   a, b, (((np.ndim(a) - 1,), (np.ndim(b) - 1 - b_is_mat,)), (a_batch, b_batch)),
#     245   precision=precision, preferred_element_type=preferred_element_type)
#     246 result = lax.transpose(out, perm)
#     247 return lax_internal._convert_element_type(result, preferred_element_type, output_weak_type)
#
#     [... skipping hidden 8 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/lax.py:4647, in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type, out_sharding)
#    4644 if not core.definitely_equal_shape(lhs_contracting_shape, rhs_contracting_shape):
#    4645   msg = ("dot_general requires contracting dimensions to have the same "
#    4646          "shape, got {} and {}.")
# -> 4647   raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    4649 return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (20,) and (2,).
